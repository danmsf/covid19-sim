# %%
import numpy as np
import pandas as pd
from OLG_model_src import Parameters2, OLG
import altair as alt


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
countrydata_df = pd.read_csv('countrydata_df.csv', parse_dates=['date'])[['Country', 'StringencyIndex', 'date', 'I']]

# %%
contagion_pi_country_dict = {'Austria' :-0.21,
'Belgium':-0.24,
'Bulgaria':-0.88,
'Croatia':-0.2,
'Cyprus':-0.06,
'Denmark':-0.21,
'Finland':-0.16,
'France':-0.39
}


scenario = {'t': {0: 20, 1: 10},
            'R0D': {0: 0, 1: 0}}

p = Parameters2(tau=14, 
                init_infected=100, 
                fi=0.25, 
                theta=0.0771, 
                countries=['France'], 
                scenario=scenario, 
                comparator_country='Germany', 
                contagion_pi_country=contagion_pi_country_dict.get('France'))

# %%
# plese note that R is moving average
olg = OLG(countrydata_df, p)
# Out:
# C:\Users\User\Miniconda3\envs\py37\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
countrydata_df.query('Country=="France" & I > 100')
# Out:
#      Country  StringencyIndex       date        I
# 1040  France             38.0 2020-03-01    116.0
# 1041  France             38.0 2020-03-02    176.0
# 1042  France             43.0 2020-03-03    196.0
# 1043  France             43.0 2020-03-04    269.0
# 1044  France             43.0 2020-03-05    404.0
# 1045  France             43.0 2020-03-06    632.0
# 1046  France             43.0 2020-03-07    921.0
# 1047  France             43.0 2020-03-08   1178.0
# 1048  France             43.0 2020-03-09   1370.0
# 1049  France             43.0 2020-03-10   1739.0
# 1050  France             43.0 2020-03-11   2221.0
# 1051  France             43.0 2020-03-12   2803.0
# 1052  France             43.0 2020-03-13   3570.0
# 1053  France             52.0 2020-03-14   4366.0
# 1054  France             57.0 2020-03-15   5284.0
# 1055  France             67.0 2020-03-16   6473.0
# 1056  France             81.0 2020-03-17   6953.0
# 1057  France             81.0 2020-03-18   6953.0
# 1058  France             81.0 2020-03-19   8268.0
# 1059  France             81.0 2020-03-20   9328.0
# 1060  France             86.0 2020-03-21  10575.0
# 1061  France             86.0 2020-03-22  12310.0
# 1062  France             86.0 2020-03-23  13144.0
# 1063  France             86.0 2020-03-24  16796.0
# 1064  France             86.0 2020-03-25  17923.0
# 1065  France             86.0 2020-03-26  20002.0
# 1066  France             86.0 2020-03-27  22511.0
# 1067  France             86.0 2020-03-28  25269.0
# 1068  France             86.0 2020-03-29  29561.0
# 1069  France             86.0 2020-03-30  30366.0
# 1070  France              NaN 2020-03-31  33599.0
# 1071  France              NaN 2020-04-01  39161.0
# 1072  France              NaN 2020-04-02  42022.0
# 1073  France              NaN 2020-04-03  41290.0
# 1074  France              NaN 2020-04-04  61650.0
# 1075  France              NaN 2020-04-05  66955.0
# 1076  France              NaN 2020-04-06  68578.0
# 1077  France              NaN 2020-04-07  71849.0
# 1078  France              NaN 2020-04-08  79404.0
# 1079  France              NaN 2020-04-09  80827.0

# %%
pd.set_option('display.column_space', 25)

olg.df[37:43][['R', 'I', 'corona_days','prediction_ind']]
# Out:
#            R              I  corona_days  prediction_ind
# 37  1.492807   71849.000000           38               0
# 38  1.718673   79404.000000           39               0
# 39  0.634051   80827.000000           40               1
# 40  1.985502  141296.143672           41               1
# 41  1.985502  158322.251644           42               1
# 42  1.985502  185073.357483           43               1

# %%
# var_in_multi_line selects one of the 3 variables: I, E, A in the country comparison plot
olg.plot_data(p.countries, var_in_multi_line='I')
# Out:
# alt.LayerChart(...)

# %%
# due to sequantial days witout a change  some R_contagion_score behaved iradicly, so a limit of <10 on the variable was used 
olg.plot_data_contagion_score()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-52124b13c3d3> in <module>
#       1 # due to sequantial days witout a change  some R_contagion_score behaved iradicly, so a limit of <10 on the variable was used
# ----> 2 olg.plot_data_contagion_score()
#
# ~\git\covid19-sim\OLG_model_src.py in plot_data_contagion_score(self)
#     235         plot_df = plot_df.melt(id_vars=['corona_days'], value_vars=['StringencyIndex', 'r_values']).dropna()
#     236
# --> 237         plot_df_contagion = self.df.query('prediction_ind==0')[['corona_days', 'R_contagion_score']]
#     238         # plot_df_contagion['R_contagion_score'].clip(upper=10, inplace=True)
#     239         plot_df_contagion = plot_df_contagion.melt(id_vars=['corona_days'], value_vars=['R_contagion_score'])
#
# ~\Miniconda3\envs\py37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Miniconda3\envs\py37\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\Miniconda3\envs\py37\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['R_contagion_score'] not in index"

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, Holt

# %%
saledata = olg.df[olg.df['r_values'].notnull()]['r_values']
saledata[-14:]
# Out:
# 15    2.006116
# 16    2.163137
# 17    2.844049
# 18    2.720070
# 19    1.548673
# 20    1.850343
# 21    2.248257
# 22    2.253940
# 23    1.144804
# 24    1.131810
# 25    1.383845
# 26    1.346690
# 27    1.123523
# 28    0.963037
# Name: r_values, dtype: float64

# %%
fit1 = Holt(saledata).fit(smoothing_level=0.8, smoothing_slope=0.2, optimized=False)
fcast1 = fit1.forecast(30).rename("Holt's linear trend")

fit2 = Holt(saledata[-14:], exponential=True).fit(smoothing_level=0.8, smoothing_slope=0.2, optimized=False)
fcast2 = fit2.forecast(30).rename("Exponential trend")

fit3 = Holt(saledata, exponential=True).fit(smoothing_level=0.8, smoothing_slope=0.2)
fcast3 = fit3.forecast(30).rename("Additive damped trend")


fit1.fittedvalues.plot(marker="o", color='blue')
fcast1.plot(color='blue', marker="o", legend=True)

fit2.fittedvalues.plot(marker="x", color='red')
fcast2.plot(color='red', marker="x", legend=True)

fit3.fittedvalues.plot(marker=".", color='green')
fcast3.plot(color='green', marker=".", legend=True)

# plt.show()
# Out:
# C:\Users\User\Miniconda3\envs\py37\lib\site-packages\statsmodels\tsa\base\tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Miniconda3\envs\py37\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
fcast3
# Out:
# 29    0.927704
# 30    0.867651
# 31    0.811485
# 32    0.758955
# 33    0.709825
# 34    0.663876
# 35    0.620901
# 36    0.580708
# 37    0.543117
# 38    0.507959
# 39    0.475077
# 40    0.444324
# 41    0.415561
# 42    0.388661
# 43    0.363501
# 44    0.339971
# 45    0.317963
# 46    0.297381
# 47    0.278130
# 48    0.260126
# 49    0.243287
# 50    0.227538
# 51    0.212809
# 52    0.199033
# 53    0.186149
# 54    0.174099
# 55    0.162829
# 56    0.152289
# 57    0.142430
# 58    0.133210
# Name: Additive damped trend, dtype: float64
